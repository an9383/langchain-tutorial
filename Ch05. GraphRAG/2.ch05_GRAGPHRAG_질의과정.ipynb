# %%
# !pip install graphrag

# %%
# # 구글 드라이브 마운트
# from google.colab import drive
# drive.mount('/content/drive')

# %%
# 작업 디렉토리 변경
import os
os.chdir(r"D:\WorkSpace\Python\langchain-tutorial")

# 현재 작업 디렉토리 확인
print("현재 작업 디렉토리:")
from pathlib import Path
print(Path.cwd())
# Out:
# 현재 작업 디렉토리:
# D:\WorkSpace\Python\langchain-tutorial

# %% [markdown]
# ### 1. 포괄적인 질문
# "이 문서에서 다루는 주요 투자 수단들의 종류는 무엇인가요?"

# %%
import os
from dotenv import load_dotenv

# .env 파일에서 환경 변수 로드
load_dotenv("/content/.env")

# 환경 변수에서 API 키 가져오기
os.environ["OPENAI_API_KEY"] = os.getenv("OPENAI_API_KEY")

# !graphrag index \
--root "D:\WorkSpace\Python\langchain-tutorial\Ch05. GraphRAG"

# 글로벌 서치
# !graphrag query \
--root "D:\WorkSpace\Python\langchain-tutorial\Ch05. GraphRAG" \
--method global \
--query "채권의 전환성 개념이 각 컬터들에서 어떻게 소개되었나요?"
# Out:
# ^C

# %%
# 로컬 서치
# !graphrag query \
--root "D:\WorkSpace\Python\langchain-tutorial\Ch05. GraphRAG" \
--method local \
--query "채권의 '전환성' 개념이 각 챕터들에서 어떻게 소개되어있나요?"
# Out:
# ┌───────────────────── Traceback (most recent call last) ─────────────────────┐
# │ d:\WorkSpace\Python\langchain-tutorial\Ch05.                                │
# │ GraphRAG\venv\lib\site-packages\graphrag\cli\main.py:493 in _query_cli      │
# │                                                                             │
# │   490 │   ),                                                                │
# │   491 ) -> None:                                                            │
# │   492 │   """Query a knowledge graph index."""                              │
# │ > 493 │   from graphrag.cli.query import (                                  │
# │   494 │   │   run_basic_search,                                             │
# │   495 │   │   run_drift_search,                                             │
# │   496 │   │   run_global_search,                                            │
# │                                                                             │
# │ d:\WorkSpace\Python\langchain-tutorial\Ch05.                                │
# │ GraphRAG\venv\lib\site-packages\graphrag\cli\query.py:11 in <module>        │
# │                                                                             │
# │     8 from pathlib import Path                                              │
# │     9 from typing import TYPE_CHECKING, Any                                 │
# │    10                                                                       │
# │ >  11 import graphrag.api as api                                            │
# │    12 from graphrag.callbacks.noop_query_callbacks import NoopQueryCallback │
# │    13 from graphrag.config.load_config import load_config                   │
# │    14 from graphrag.config.models.graph_rag_config import GraphRagConfig    │
# │                                                                             │
# │ d:\WorkSpace\Python\langchain-tutorial\Ch05.                                │
# │ GraphRAG\venv\lib\site-packages\graphrag\api\__init__.py:11 in <module>     │
# │                                                                             │
# │    8 """                                                                    │
# │    9                                                                        │
# │   10 from graphrag.api.index import build_index                             │
# │ > 11 from graphrag.api.prompt_tune import generate_indexing_prompts         │
# │   12 from graphrag.api.query import (                                       │
# │   13 │   basic_search,                                                      │
# │   14 │   basic_search_streaming,                                            │
# │                                                                             │
# │ d:\WorkSpace\Python\langchain-tutorial\Ch05.                                │
# │ GraphRAG\venv\lib\site-packages\graphrag\api\prompt_tune.py:48 in <module>  │
# │                                                                             │
# │    45 )                                                                     │
# │    46 from graphrag.prompt_tune.generator.language import detect_language   │
# │    47 from graphrag.prompt_tune.generator.persona import generate_persona   │
# │ >  48 from graphrag.prompt_tune.loader.input import load_docs_in_chunks     │
# │    49 from graphrag.prompt_tune.types import DocSelectionType               │
# │    50 from graphrag.tokenizer.get_tokenizer import get_tokenizer            │
# │    51                                                                       │
# │                                                                             │
# │ d:\WorkSpace\Python\langchain-tutorial\Ch05.                                │
# │ GraphRAG\venv\lib\site-packages\graphrag\prompt_tune\loader\input.py:30 in  │
# │ <module>                                                                    │
# │                                                                             │
# │    27                                                                       │
# │    28 def _sample_chunks_from_embeddings(                                   │
# │    29 │   text_chunks: pd.DataFrame,                                        │
# │ >  30 │   embeddings: np.ndarray[float, np.dtype[np.float_]],               │
# │    31 │   k: int = K,                                                       │
# │    32 ) -> pd.DataFrame:                                                    │
# │    33 │   """Sample text chunks from embeddings."""                         │
# │                                                                             │
# │ d:\WorkSpace\Python\langchain-tutorial\Ch05.                                │
# │ GraphRAG\venv\lib\site-packages\numpy\__init__.py:413 in __getattr__        │
# │                                                                             │
# │   410 │   │   │   raise AttributeError(__former_attrs__[attr], name=None)   │
# │   411 │   │                                                                 │
# │   412 │   │   if attr in __expired_attributes__:                            │
# │ > 413 │   │   │   raise AttributeError(                                     │
# │   414 │   │   │   │   f"`np.{attr}` was removed in the NumPy 2.0 release. " │
# │   415 │   │   │   │   f"{__expired_attributes__[attr]}",                    │
# │   416 │   │   │   │   name=None                                             │
# └─────────────────────────────────────────────────────────────────────────────┘
# AttributeError: `np.float_` was removed in the NumPy 2.0 release. Use
# `np.float64` instead.

# %% [markdown]
# ### 2. 세부적인 질문
# "산업채권 평가시 순유동자산(Net Quick Assets)을 어떻게 분석해야 하나요?"

# %%
# 글로벌 서치
# !graphrag query \
--root "D:\WorkSpace\Python\langchain-tutorial\Ch05. GraphRAG" \
--method global \
--query "산업채권 평가시 순유동자산(Net Quick Assets)을 어떻게 분석해야 하나요?"
# Out:
# ┌───────────────────── Traceback (most recent call last) ─────────────────────┐
# │ d:\WorkSpace\Python\langchain-tutorial\Ch05.                                │
# │ GraphRAG\venv\lib\site-packages\graphrag\cli\main.py:493 in _query_cli      │
# │                                                                             │
# │   490 │   ),                                                                │
# │   491 ) -> None:                                                            │
# │   492 │   """Query a knowledge graph index."""                              │
# │ > 493 │   from graphrag.cli.query import (                                  │
# │   494 │   │   run_basic_search,                                             │
# │   495 │   │   run_drift_search,                                             │
# │   496 │   │   run_global_search,                                            │
# │                                                                             │
# │ d:\WorkSpace\Python\langchain-tutorial\Ch05.                                │
# │ GraphRAG\venv\lib\site-packages\graphrag\cli\query.py:11 in <module>        │
# │                                                                             │
# │     8 from pathlib import Path                                              │
# │     9 from typing import TYPE_CHECKING, Any                                 │
# │    10                                                                       │
# │ >  11 import graphrag.api as api                                            │
# │    12 from graphrag.callbacks.noop_query_callbacks import NoopQueryCallback │
# │    13 from graphrag.config.load_config import load_config                   │
# │    14 from graphrag.config.models.graph_rag_config import GraphRagConfig    │
# │                                                                             │
# │ d:\WorkSpace\Python\langchain-tutorial\Ch05.                                │
# │ GraphRAG\venv\lib\site-packages\graphrag\api\__init__.py:11 in <module>     │
# │                                                                             │
# │    8 """                                                                    │
# │    9                                                                        │
# │   10 from graphrag.api.index import build_index                             │
# │ > 11 from graphrag.api.prompt_tune import generate_indexing_prompts         │
# │   12 from graphrag.api.query import (                                       │
# │   13 │   basic_search,                                                      │
# │   14 │   basic_search_streaming,                                            │
# │                                                                             │
# │ d:\WorkSpace\Python\langchain-tutorial\Ch05.                                │
# │ GraphRAG\venv\lib\site-packages\graphrag\api\prompt_tune.py:48 in <module>  │
# │                                                                             │
# │    45 )                                                                     │
# │    46 from graphrag.prompt_tune.generator.language import detect_language   │
# │    47 from graphrag.prompt_tune.generator.persona import generate_persona   │
# │ >  48 from graphrag.prompt_tune.loader.input import load_docs_in_chunks     │
# │    49 from graphrag.prompt_tune.types import DocSelectionType               │
# │    50 from graphrag.tokenizer.get_tokenizer import get_tokenizer            │
# │    51                                                                       │
# │                                                                             │
# │ d:\WorkSpace\Python\langchain-tutorial\Ch05.                                │
# │ GraphRAG\venv\lib\site-packages\graphrag\prompt_tune\loader\input.py:30 in  │
# │ <module>                                                                    │
# │                                                                             │
# │    27                                                                       │
# │    28 def _sample_chunks_from_embeddings(                                   │
# │    29 │   text_chunks: pd.DataFrame,                                        │
# │ >  30 │   embeddings: np.ndarray[float, np.dtype[np.float_]],               │
# │    31 │   k: int = K,                                                       │
# │    32 ) -> pd.DataFrame:                                                    │
# │    33 │   """Sample text chunks from embeddings."""                         │
# │                                                                             │
# │ d:\WorkSpace\Python\langchain-tutorial\Ch05.                                │
# │ GraphRAG\venv\lib\site-packages\numpy\__init__.py:413 in __getattr__        │
# │                                                                             │
# │   410 │   │   │   raise AttributeError(__former_attrs__[attr], name=None)   │
# │   411 │   │                                                                 │
# │   412 │   │   if attr in __expired_attributes__:                            │
# │ > 413 │   │   │   raise AttributeError(                                     │
# │   414 │   │   │   │   f"`np.{attr}` was removed in the NumPy 2.0 release. " │
# │   415 │   │   │   │   f"{__expired_attributes__[attr]}",                    │
# │   416 │   │   │   │   name=None                                             │
# └─────────────────────────────────────────────────────────────────────────────┘
# AttributeError: `np.float_` was removed in the NumPy 2.0 release. Use
# `np.float64` instead.

# %%
# 로컬 서치
# !graphrag query \
--root "D:\WorkSpace\Python\langchain-tutorial\Ch05. GraphRAG" \
--method local \
--query "산업채권 평가시 순유동자산(Net Quick Assets)을 어떻게 분석해야 하나요?"
# Out:
# ┌───────────────────── Traceback (most recent call last) ─────────────────────┐
# │ d:\WorkSpace\Python\langchain-tutorial\Ch05.                                │
# │ GraphRAG\venv\lib\site-packages\graphrag\cli\main.py:493 in _query_cli      │
# │                                                                             │
# │   490 │   ),                                                                │
# │   491 ) -> None:                                                            │
# │   492 │   """Query a knowledge graph index."""                              │
# │ > 493 │   from graphrag.cli.query import (                                  │
# │   494 │   │   run_basic_search,                                             │
# │   495 │   │   run_drift_search,                                             │
# │   496 │   │   run_global_search,                                            │
# │                                                                             │
# │ d:\WorkSpace\Python\langchain-tutorial\Ch05.                                │
# │ GraphRAG\venv\lib\site-packages\graphrag\cli\query.py:11 in <module>        │
# │                                                                             │
# │     8 from pathlib import Path                                              │
# │     9 from typing import TYPE_CHECKING, Any                                 │
# │    10                                                                       │
# │ >  11 import graphrag.api as api                                            │
# │    12 from graphrag.callbacks.noop_query_callbacks import NoopQueryCallback │
# │    13 from graphrag.config.load_config import load_config                   │
# │    14 from graphrag.config.models.graph_rag_config import GraphRagConfig    │
# │                                                                             │
# │ d:\WorkSpace\Python\langchain-tutorial\Ch05.                                │
# │ GraphRAG\venv\lib\site-packages\graphrag\api\__init__.py:11 in <module>     │
# │                                                                             │
# │    8 """                                                                    │
# │    9                                                                        │
# │   10 from graphrag.api.index import build_index                             │
# │ > 11 from graphrag.api.prompt_tune import generate_indexing_prompts         │
# │   12 from graphrag.api.query import (                                       │
# │   13 │   basic_search,                                                      │
# │   14 │   basic_search_streaming,                                            │
# │                                                                             │
# │ d:\WorkSpace\Python\langchain-tutorial\Ch05.                                │
# │ GraphRAG\venv\lib\site-packages\graphrag\api\prompt_tune.py:48 in <module>  │
# │                                                                             │
# │    45 )                                                                     │
# │    46 from graphrag.prompt_tune.generator.language import detect_language   │
# │    47 from graphrag.prompt_tune.generator.persona import generate_persona   │
# │ >  48 from graphrag.prompt_tune.loader.input import load_docs_in_chunks     │
# │    49 from graphrag.prompt_tune.types import DocSelectionType               │
# │    50 from graphrag.tokenizer.get_tokenizer import get_tokenizer            │
# │    51                                                                       │
# │                                                                             │
# │ d:\WorkSpace\Python\langchain-tutorial\Ch05.                                │
# │ GraphRAG\venv\lib\site-packages\graphrag\prompt_tune\loader\input.py:30 in  │
# │ <module>                                                                    │
# │                                                                             │
# │    27                                                                       │
# │    28 def _sample_chunks_from_embeddings(                                   │
# │    29 │   text_chunks: pd.DataFrame,                                        │
# │ >  30 │   embeddings: np.ndarray[float, np.dtype[np.float_]],               │
# │    31 │   k: int = K,                                                       │
# │    32 ) -> pd.DataFrame:                                                    │
# │    33 │   """Sample text chunks from embeddings."""                         │
# │                                                                             │
# │ d:\WorkSpace\Python\langchain-tutorial\Ch05.                                │
# │ GraphRAG\venv\lib\site-packages\numpy\__init__.py:413 in __getattr__        │
# │                                                                             │
# │   410 │   │   │   raise AttributeError(__former_attrs__[attr], name=None)   │
# │   411 │   │                                                                 │
# │   412 │   │   if attr in __expired_attributes__:                            │
# │ > 413 │   │   │   raise AttributeError(                                     │
# │   414 │   │   │   │   f"`np.{attr}` was removed in the NumPy 2.0 release. " │
# │   415 │   │   │   │   f"{__expired_attributes__[attr]}",                    │
# │   416 │   │   │   │   name=None                                             │
# └─────────────────────────────────────────────────────────────────────────────┘
# AttributeError: `np.float_` was removed in the NumPy 2.0 release. Use
# `np.float64` instead.
