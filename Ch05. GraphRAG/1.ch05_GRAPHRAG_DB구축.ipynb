# %%
# !pip install graphrag

# %%
from pathlib import Path

working_dir = Path("D:\WorkSpace\Python\langchain-tutorial\Ch05. GraphRAG")
working_dir.mkdir(parents=True, exist_ok=True)

# %%
import os
# !graphrag init --root "D:\WorkSpace\Python\langchain-tutorial\Ch05. GraphRAG" --force
# !graphrag index \
--root "D:\WorkSpace\Python\langchain-tutorial\Ch05. GraphRAG"
# Out:
# ^C

# %%
from pathlib import Path

# Define the path using Path object
input_dir = Path(r'D:\WorkSpace\Python\langchain-tutorial\Ch05. GraphRAG\input')

# Now mkdir works
input_dir.mkdir(parents=True, exist_ok=True)
# Out:
# ---------------------------------------------------------------------------
# AttributeError                            Traceback (most recent call last)
# Cell In[27], line 3
#       1 # 워킹 디렉토리 안에 input폴더 생성
#       2 input_dir = 'D:\WorkSpace\Python\langchain-tutorial\Ch05. GraphRAG\input'
# ----> 3 input_dir.mkdir(parents=True, exist_ok=True)
#
# AttributeError: 'str' object has no attribute 'mkdir'

# %%
import shutil
import os
# from google.colab import drive

# # 먼저 구글 드라이브 마운트
# drive.mount('/content/drive')

# 소스 및 대상 경로 정의
source_path = 'D:\WorkSpace\Python\langchain-tutorial\Ch05. GraphRAG\Data\How_to_invest_money.txt'
destination_path = 'D:\WorkSpace\Python\langchain-tutorial\Ch05. GraphRAG\working_directory\input\How_to_invest_money.txt'

# 파일 복사
shutil.copy(source_path, destination_path)

# 파일이 성공적으로 복사되었는지 확인
if os.path.exists(destination_path):
    print(f"파일이 {destination_path}에 성공적으로 복사되었습니다")
else:
    print("파일 복사 실패")
# Out:
# 파일이 D:\WorkSpace\Python\langchain-tutorial\Ch05. GraphRAG\working_directory\input\How_to_invest_money.txt에 성공적으로 복사되었습니다

# %%
# !graphrag index --root ./working_directory --method standard --logger print

# !graphrag index --root ./working_directory --method standard print
# Out:
# ┌───────────────────── Traceback (most recent call last) ─────────────────────┐
# │ d:\WorkSpace\Python\langchain-tutorial\Ch05.                                │
# │ GraphRAG\venv\lib\site-packages\graphrag\cli\main.py:116 in _initialize_cli │
# │                                                                             │
# │   113 │   """Generate a default configuration file."""                      │
# │   114 │   from graphrag.cli.initialize import initialize_project_at         │
# │   115 │                                                                     │
# │ > 116 │   initialize_project_at(path=root, force=force)                     │
# │   117                                                                       │
# │   118                                                                       │
# │   119 @app.command("index")                                                 │
# │                                                                             │
# ...

# %%
# # working_directory 폴더를 구글 드라이브로 복사
# !cp -r /content/working_directory "/content/drive/My Drive/"
